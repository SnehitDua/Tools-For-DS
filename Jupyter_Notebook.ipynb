# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Snehit Dua</b><br>
# Data Scientist (Desired Occupation)

# %% [markdown]
# <i>I am interested in data science because a Data Scientist earns a good amount of money.</i>

# %% [markdown]
# ### The below code prints Hola

# %%
print('Hola')
# Out:
# Hola

# %% [markdown]
# | Column1 | Column2 |
# | ------ | ------ |
# | cell | cell |
#
# <a href= "https://www.coursera.org/">Coursera</a><br><br>
# Sample python code:<br>
# ```python
# a = 69
# ```
